# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.utils import np_utils
from sklearn import datasets
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
iris = datasets.load_iris()
X, y = iris.data, iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)

y_train_one_hot = np_utils.to_categorical(y_train)
y_test_one_hot = np_utils.to_categorical(y_test)

# %%
epochs = 40
max_batch = 100

# %%
batch_size = []
accuracies = []

for i in range(1, max_batch+1, 5):
    print(f'Batch Size: {i}')
    model = Sequential()
    model.add(Dense(16, input_shape=(4,)))
    model.add(Activation('sigmoid'))
    model.add(Dropout(3))
    model.add(Dense(3))
    model.add(Activation('softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    model.fit(X_train, y_train_one_hot, epochs=epochs, batch_size=i, verbose=1)
    loss, accuracy = model.evaluate(X_test, y_test_one_hot, verbose=1)
    print(f'accuracy: {accuracy}')
    batch_size.append(i)
    accuracies.append(accuracy)
# Out:
# Batch Size: 1
# Epoch 1/40
# 100/100 [==============================] - 8s 77ms/step - loss: 1.1460 - acc: 0.3400
# Epoch 2/40
# 100/100 [==============================] - 1s 7ms/step - loss: 1.0166 - acc: 0.5000
# Epoch 3/40
# 100/100 [==============================] - 1s 7ms/step - loss: 0.9680 - acc: 0.5800
# Epoch 4/40
# 100/100 [==============================] - 1s 7ms/step - loss: 0.9176 - acc: 0.6900
# Epoch 5/40
# 100/100 [==============================] - 1s 7ms/step - loss: 0.8620 - acc: 0.6900
# Epoch 6/40
# 100/100 [==============================] - 1s 7ms/step - loss: 0.8064 - acc: 0.6900
# Epoch 7/40
# 100/100 [==============================] - 1s 7ms/step - loss: 0.7574 - acc: 0.6900
# Epoch 8/40
# 100/100 [==============================] - 1s 6ms/step - loss: 0.7181 - acc: 0.7000
# Epoch 9/40
# 100/100 [==============================] - 1s 6ms/step - loss: 0.6812 - acc: 0.6900
# Epoch 10/40
# ...

# %%
plt.plot(batch_size, accuracies)

# %%
plt.plot(batch_size, accuracies)

# %%
batch_size = []
accuracies = []

for i in range(1, max_batch+1):
    print(f'Batch Size: {i}')
    model = Sequential()
    model.add(Dense(16, input_shape=(4,)))
    model.add(Activation('sigmoid'))
    model.add(Dense(3))
    model.add(Activation('softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    model.fit(X_train, y_train_one_hot, epochs=epochs, batch_size=i, verbose=1)
    loss, accuracy = model.evaluate(X_test, y_test_one_hot, verbose=1)
    print(f'accuracy: {accuracy}')
    batch_size.append(i)
    accuracies.append(accuracy)
